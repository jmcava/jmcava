# %% [markdown]
# <a href="https://colab.research.google.com/github/jmcava/jmcava/blob/main/Dados_Socioeconomicos_no_Rudge_Ramos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tabela 1
print("Tabela 1 - População residente nos censos demográficos 2000 e 2010 e estimativa 2021:")
print(" Ano   População  Fonte")
print("2000   43.879     IBGE - Censos Demográficos e Estimativas")
print("2010   N/A        IBGE - Censos Demográficos e Estimativas")
print("2021   N/A        IBGE - Censos Demográficos e Estimativas\n")

# Tabela 2
print("Tabela 2 - Taxa geométrica de crescimento anual (TGCA) da população, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2000/2010 e 2010/2021:")
print("TGCA (%)   Período   Fonte")
print("    0,68    2000/2010  IBGE - Censos Demográficos e Estimativas")
print("    0,34    2010/2021  IBGE - Censos Demográficos e Estimativas\n")

# Tabela 3
print("Tabela 3 - Evolução da participação da população no total do município, bairro Rudge Ramos, São Bernardo do Campo, 1980 a 2021:")
print(" Ano    Participação (%)   Fonte")
print("1980          N/A         IBGE - Censos Demográficos e Estimativas")
print("2021         5,16         IBGE - Censos Demográficos e Estimativas\n")

# Tabela 4
print("Tabela 4 - Densidade demográfica (Habitante por Km²), bairro Rudge Ramos e total do município de São Bernardo do Campo, 2021:")
print("           Localidade             Densidade Demográfica (Habitantes por Km²)")
print("   Bairro Rudge Ramos                         9.527")
print("São Bernardo do Campo                        N/A")
# Out:
# Tabela 1 - População residente nos censos demográficos 2000 e 2010 e estimativa 2021:
#  Ano   População  Fonte
# 2000   43.879     IBGE - Censos Demográficos e Estimativas
# 2010   N/A        IBGE - Censos Demográficos e Estimativas
# 2021   N/A        IBGE - Censos Demográficos e Estimativas
#
# Tabela 2 - Taxa geométrica de crescimento anual (TGCA) da população, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2000/2010 e 2010/2021:
# TGCA (%)   Período   Fonte
#     0,68    2000/2010  IBGE - Censos Demográficos e Estimativas
#     0,34    2010/2021  IBGE - Censos Demográficos e Estimativas
#
# Tabela 3 - Evolução da participação da população no total do município, bairro Rudge Ramos, São Bernardo do Campo, 1980 a 2021:
#  Ano    Participação (%)   Fonte
# 1980          N/A         IBGE - Censos Demográficos e Estimativas
# 2021         5,16         IBGE - Censos Demográficos e Estimativas
#
# ...

# %%
import pandas as pd

# Tabela 1
dados_tabela_1 = {
    'Ano': ['2000', '2010', '2021'],
    'População': ['43.879', 'N/A', 'N/A'],
    'Fonte': ['IBGE - Censos Demográficos e Estimativas', 'IBGE - Censos Demográficos e Estimativas', 'IBGE - Censos Demográficos e Estimativas']
}
df_tabela_1 = pd.DataFrame(dados_tabela_1)

# Tabela 2
dados_tabela_2 = {
    'TGCA (%)': ['0,68', '0,34'],
    'Período': ['2000/2010', '2010/2021'],
    'Fonte': ['IBGE - Censos Demográficos e Estimativas', 'IBGE - Censos Demográficos e Estimativas']
}
df_tabela_2 = pd.DataFrame(dados_tabela_2)

# Tabela 3
dados_tabela_3 = {
    'Ano': ['1980', '2021'],
    'Participação (%)': ['N/A', '5,16'],
    'Fonte': ['IBGE - Censos Demográficos e Estimativas', 'IBGE - Censos Demográficos e Estimativas']
}
df_tabela_3 = pd.DataFrame(dados_tabela_3)

# Tabela 4
dados_tabela_4 = {
    'Localidade': ['Bairro Rudge Ramos', 'São Bernardo do Campo'],
    'Densidade Demográfica (Habitantes por Km²)': ['9.527', 'N/A']
}
df_tabela_4 = pd.DataFrame(dados_tabela_4)

# Tabela 5
dados_tabela_5 = {
    'Faixa Etária (anos)': ['Até 3', '4 e 5', '6 a 10', '11 a 14', '15 a 19', '20 a 29', '30 a 39', '40 a 49', '50 a 59', '60 e mais', 'Sem informação'],
    'Bairro Rudge Ramos': [1583, 748, 1905, 1733, 2529, 7069, 6902, 6330, 5764, 7722, 2],
    'Total do Município': [39187, 19951, 52240, 47166, 59675, 140617, 131493, 112369, 84206, 77838, 721]
}
df_tabela_5 = pd.DataFrame(dados_tabela_5)

# Tabela 6
dados_tabela_6 = {
    'Região': ['Bairro Rudge Ramos', 'São Bernardo do Campo'],
    '0 a 14 anos': ['14,1%', '20,7%'],
    '15 a 29 anos': ['22,7%', '26,2%'],
    '30 a 59 anos': ['44,9%', '42,9%'],
    '60 anos e mais': ['18,3%', '10,2%']
}
df_tabela_6 = pd.DataFrame(dados_tabela_6)

# Tabela 7
dados_tabela_7 = {
    'Região': ['Bairro Rudge Ramos'],
    'População de 10 anos e mais Não Alfabetizada - 2010': ['1,0%']
}
df_tabela_7 = pd.DataFrame(dados_tabela_7)

# Tabela 8
dados_tabela_8 = {
    'Sexo': ['Masculino', 'Feminino'],
    'Bairro Rudge Ramos': [19596, 22689],
    'Total do Município': ['N/A', 'N/A']
}
df_tabela_8 = pd.DataFrame(dados_tabela_8)

# Tabela 9
dados_tabela_9 = {
    'Cor ou Raça': ['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'Sem Declaração'],
    'População (%) Bairro Rudge Ramos': ['84,8%', '2,3%', '9,7%', '3,1%', '-', '-'],
    'População (%) São Bernardo do Campo': ['64,4%', '4,9%', '28,7%', '1,8%', '0,1%', '0,1%']
}
df_tabela_9 = pd.DataFrame(dados_tabela_9)

# Tabela 10
dados_tabela_10 = {
    'Serviço': ['Rede geral de água', 'Rede geral de esgoto', 'Lixo coletado', 'Energia de companhia distribuidora'],
    'Bairro Rudge Ramos': ['99,9%', '99,7%', '99,9%', '100,0%']
}
df_tabela_10 = pd.DataFrame(dados_tabela_10)

# Tabela 11
dados_tabela_11 = {
    'Tipo de Ensino': ['Estadual', 'Municipal'],
    'Creche': ['-', '396'],
    'Pré-escola': ['-', '467'],
    'Fundamental - Anos Iniciais': ['-', '1289'],
    'Fundamental - Anos Finais': ['970', '-'],
    'Ensino Médio': ['770', '-'],
    'Supletivo Fundamental': ['107', '-'],
    'Supletivo Médio': ['228', '-']
}
df_tabela_11 = pd.DataFrame(dados_tabela_11)

# Tabela 12
dados_tabela_12 = {
    'Região': ['Bairro Rudge Ramos'],
    'Domicílios Particulares Permanentes': [14874],
    'Média de Morador por Domicílio': [2.8]
}
df_tabela_12 = pd.DataFrame(dados_tabela_12)

# Tabela 13
dados_tabela_13 = {
    'Região': ['Bairro Rudge Ramos'],
    'População de 10 anos e mais Não Alfabetizada - 2010': ['1,0%']
}
df_tabela_13 = pd.DataFrame(dados_tabela_13)

# Tabela 15
dados_tabela_15 = {
    'Tipo de ensino': ['Estadual', 'Municipal'],
    'Creche': ['-', '396'],
    'Pré-escola': ['-', '467'],
    'Fundamental - Anos Iniciais': ['-', '1289'],
    'Fundamental - Anos Finais': ['970', '-'],
    'Ensino Médio': ['770', '-'],
    'Supletivo Fundamental': ['107', '-'],
    'Supletivo Médio': ['228', '-']
}
df_tabela_15 = pd.DataFrame(dados_tabela_15)

# Tabela 16
dados_tabela_16 = {
    'Área': ['Cultura', 'Educação', 'Esporte e Lazer', 'Saúde', 'Segurança Pública - GCM', 'Utilidade Pública', 'Praças Públicas'],
    'Número de Equipamentos': [3, 9, 6, 9, 1, 1, 56]
}
df_tabela_16 = pd.DataFrame(dados_tabela_16)

# Tabela 17
dados_tabela_17 = {
    'Região': ['Bairro Rudge Ramos', 'São Bernardo do Campo'],
    'Indústria': [434, 'N/A'],
    'Construção Civil': [425, 'N/A'],
    'Serviço': [6018, 'N/A'],
    'Comércio': [2006, 'N/A'],
    'Agropecuária': [4, 'N/A']
}
df_tabela_17 = pd.DataFrame(dados_tabela_17)

# Imprimindo as tabelas
print("Tabela 1 - População residente nos censos demográficos 2000 e 2010 e estimativa 2021:")
print(df_tabela_1.to_string(index=False))
print("\nTabela 2 - Taxa geométrica de crescimento anual (TGCA) da população, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2000/2010 e 2010/2021:")
print(df_tabela_2.to_string(index=False))
print("\nTabela 3 - Evolução da participação da população no total do município, bairro Rudge Ramos, São Bernardo do Campo, 1980 a 2021:")
print(df_tabela_3.to_string(index=False))
print("\nTabela 4 - Densidade demográfica (Habitante por Km²), bairro Rudge Ramos e total do município de São Bernardo do Campo, 2021:")
print(df_tabela_4.to_string(index=False))
print("\nTabela 5 - População residente segundo faixa etária, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_5.to_string(index=False))
print("\nTabela 6 - Percentual da população por grupo de idade, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_6.to_string(index=False))
print("\nTabela 7 - Percentual da população de 10 anos e mais não alfabetizada, bairro Rudge Ramos:")
print(df_tabela_7.to_string(index=False))
print("\nTabela 8 - População por sexo, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_8.to_string(index=False))
print("\nTabela 9 - População por cor ou raça (em percentual), bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_9.to_string(index=False))
print("\nTabela 10 - Percentual de domicílios particulares com atendimento de serviços básicos, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_10.to_string(index=False))
print("\nTabela 11 - Número de alunos matriculados nas escolas públicas do bairro Rudge Ramos, por tipo e rede de ensino, São Bernardo do Campo, 2021:")
print(df_tabela_11.to_string(index=False))
print("\nTabela 12 - Número de domicílios particulares permanentes e média de moradores por domicílio, bairro Rudge Ramos:")
print(df_tabela_12.to_string(index=False))
print("\nTabela 13 - População por sexo, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2010:")
print(df_tabela_13.to_string(index=False))
print("\nTabela 15 - Número de equipamentos públicos por área, rede municipal, bairro Rudge Ramos, São Bernardo do Campo, 2021:")
print(df_tabela_15.to_string(index=False))
print("\nTabela 16 - Número de atividades econômicas principais instaladas por grupo CNAE, bairro Rudge Ramos e total do município, São Bernardo do Campo, 2021:")
print(df_tabela_16.to_string(index=False))
print("\nTabela 17 - Percentual de domicílios particulares por classe de rendimento domiciliar mensal per capita em salários mínimos, bairro Rudge Ramos:")
print(df_tabela_17.to_string(index=False))
# Out:
# Tabela 1 - População residente nos censos demográficos 2000 e 2010 e estimativa 2021:
#  Ano População                                    Fonte
# 2000    43.879 IBGE - Censos Demográficos e Estimativas
# 2010       N/A IBGE - Censos Demográficos e Estimativas
# 2021       N/A IBGE - Censos Demográficos e Estimativas
#
# Tabela 2 - Taxa geométrica de crescimento anual (TGCA) da população, bairro Rudge Ramos e total do município de São Bernardo do Campo, 2000/2010 e 2010/2021:
# TGCA (%)   Período                                    Fonte
#     0,68 2000/2010 IBGE - Censos Demográficos e Estimativas
#     0,34 2010/2021 IBGE - Censos Demográficos e Estimativas
#
# Tabela 3 - Evolução da participação da população no total do município, bairro Rudge Ramos, São Bernardo do Campo, 1980 a 2021:
#  Ano Participação (%)                                    Fonte
# 1980              N/A IBGE - Censos Demográficos e Estimativas
# 2021             5,16 IBGE - Censos Demográficos e Estimativas
#
# ...

# %%
import matplotlib.pyplot as plt

# Dados da tabela
faixas_etarias = ['Até 3', '4 e 5', '6 a 10', '11 a 14', '15 a 19', '20 a 29', '30 a 39', '40 a 49', '50 a 59', '60 e mais', 'Sem informação']
pop_rudge_ramos = [1583, 748, 1905, 1733, 2529, 7069, 6902, 6330, 5764, 7722, 2]
pop_total_municipio = [39187, 19951, 52240, 47166, 59675, 140617, 131493, 112369, 84206, 77838, 721]

# Calculando proporções
prop_rudge_ramos = [pop / sum(pop_rudge_ramos) * 100 for pop in pop_rudge_ramos]
prop_total_municipio = [pop / sum(pop_total_municipio) * 100 for pop in pop_total_municipio]

# Criando o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = range(len(faixas_etarias))

# Barra para o bairro Rudge Ramos
bars1 = ax.bar(index, prop_rudge_ramos, bar_width, label='Rudge Ramos')

# Barra para o total do município
bars2 = ax.bar([i + bar_width for i in index], prop_total_municipio, bar_width, label='Total do Município')

ax.set_xlabel('Faixa Etária (anos)')
ax.set_ylabel('Proporção da População (%)')
ax.set_title('Distribuição da População por Faixa Etária, Rudge Ramos')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(faixas_etarias, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados da tabela
faixas_etarias = ['0 a 14 anos', '15 a 29 anos', '30 a 59 anos', '60 anos e mais']
pop_rudge_ramos = [14.1, 22.7, 44.9, 18.3]
quantidade_pop_rudge_ramos = [1583, 2529, 7069, 7722]
pop_total_rudge_ramos = 43879  # População total do bairro Rudge Ramos em 2000

# Criando o gráfico de pizza
fig, ax = plt.subplots(figsize=(8, 8))
wedges, texts, autotexts = ax.pie(pop_rudge_ramos, labels=[""]*len(faixas_etarias), startangle=140, autopct='%1.1f%%', textprops=dict(color="w"))

# Adicionando a quantidade da população dentro das fatias
for i, (autotext, quantidade) in enumerate(zip(autotexts, quantidade_pop_rudge_ramos)):
    autotext.set_text(f'{faixas_etarias[i]} \n({quantidade})')

# Incluindo a população total do bairro Rudge Ramos
total_text = f'População Total: {pop_total_rudge_ramos}'
plt.annotate(total_text, xy=(0, 0), xytext=(-1.5, -1.5), fontsize=12, color='black')

plt.title('Distribuição Percentual da População por Grupo de Idade - Bairro Rudge Ramos')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import matplotlib.pyplot as plt

# Dados da tabela
cores_racas = ['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'Sem Declaração']
pop_rudge_ramos = [84.8, 2.3, 9.7, 3.1, 0, 0]
pop_total_municipio = [64.4, 4.9, 28.7, 1.8, 0.1, 0.1]

# Criando o gráfico de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = range(len(cores_racas))

# Barras para o bairro Rudge Ramos
bars1 = ax.bar(index, pop_rudge_ramos, bar_width, label='Rudge Ramos')

# Barras para o total do município
bars2 = ax.bar([i + bar_width for i in index], pop_total_municipio, bar_width, label='Total do Município')

ax.set_xlabel('Cor ou Raça')
ax.set_ylabel('População (%)')
ax.set_title('População por Cor ou Raça - Bairro Rudge Ramos vs. Total do Município')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(cores_racas, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados da tabela
cores_racas = ['Branca', 'Preta', 'Parda', 'Amarela', 'Indígena', 'Sem Declaração']
pop_rudge_ramos = [84.8, 2.3, 9.7, 3.1, 0, 0]
pop_total_municipio = [64.4, 4.9, 28.7, 1.8, 0.1, 0.1]
pop_total_rudge_ramos = 43879  # População total do bairro Rudge Ramos em 2010

# Calculando a quantidade de moradores no Rudge Ramos para cada cor ou raça
quantidade_pop_rudge_ramos = [round(pop * pop_total_rudge_ramos / 100) for pop in pop_rudge_ramos]

# Criando o gráfico de barras
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.35
index = range(len(cores_racas))

# Barras para o bairro Rudge Ramos
bars1 = ax.bar(index, pop_rudge_ramos, bar_width, label='Rudge Ramos')

# Barras para o total do município
bars2 = ax.bar([i + bar_width for i in index], pop_total_municipio, bar_width, label='Total do Município')

ax.set_xlabel('Cor ou Raça')
ax.set_ylabel('População (%)')
ax.set_title('População por Cor ou Raça - Bairro Rudge Ramos vs. Total do Município')
ax.set_xticks([i + bar_width / 2 for i in index])
ax.set_xticklabels(cores_racas, rotation=45, ha='right')
ax.legend()

# Adicionando os valores absolutos da população no Rudge Ramos em cada barra
for i, bar in enumerate(bars1):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), str(quantidade_pop_rudge_ramos[i]), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados da tabela
sexos = ['Masculino', 'Feminino']
pop_rudge_ramos = [19596, 22689]
pop_total_municipio = [None, None]  # N/A para o total do município

# Criando o gráfico de pizza
fig, ax = plt.subplots(figsize=(8, 8))
wedges, texts, autotexts = ax.pie(pop_rudge_ramos, labels=sexos, autopct='%1.1f%%', startangle=140, textprops=dict(color="w"))

# Adicionando o número de moradores em cada fatia
for autotext, pop in zip(autotexts, pop_rudge_ramos):
    autotext.set_text(f'{autotext.get_text()} \n({pop})')

plt.title('Distribuição da População por Sexo - Bairro Rudge Ramos')
plt.axis('equal')

plt.show()

# %% [markdown]
# Com base nos dados fornecidos, podemos começar a traçar algumas estratégias iniciais para a campanha eleitoral da Ana Nice no bairro de Rudge Ramos. Aqui estão algumas sugestões com base nos dados fornecidos:
#
# Identificar Tendências de Crescimento Populacional: A taxa geométrica de crescimento anual (TGCA) da população é uma métrica importante para entender o crescimento demográfico ao longo do tempo. Como a TGCA do bairro Rudge Ramos é de 0,68% entre 2000 e 2010 e de 0,34% entre 2010 e 2021, podemos observar uma desaceleração no crescimento populacional. No entanto, mesmo com essa desaceleração, ainda há um aumento na população, o que representa uma oportunidade para a campanha da Ana Nice expandir sua base de eleitores.
#
# Analisar a Participação da População: A evolução da participação da população no total do município mostra que o bairro de Rudge Ramos representa atualmente 5,16% da população de São Bernardo do Campo. Embora isso possa parecer uma porcentagem relativamente pequena, ainda representa uma parte significativa da população municipal. A campanha pode se concentrar em aumentar a participação dos eleitores do bairro, incentivando-os a se envolverem ativamente no processo eleitoral.
#
# Considerar a Densidade Demográfica: A densidade demográfica do bairro de Rudge Ramos é de 9.527 habitantes por km². Isso indica uma concentração relativamente alta de pessoas em uma área específica, o que pode facilitar a comunicação e o engajamento com os eleitores durante a campanha eleitoral. A equipe da Ana Nice pode aproveitar essa densidade populacional para realizar eventos de campanha, reuniões comunitárias e outras atividades de engajamento.
#
# # Personalizar Mensagens para o **Bairro**: Com base na análise dos dados demográficos e do crescimento populacional, a campanha pode personalizar suas mensagens para atender às necessidades e interesses específicos dos eleitores do bairro de Rudge Ramos. Isso pode incluir questões locais, como infraestrutura, transporte, segurança, educação e serviços públicos.
#
# Utilizar Tecnologias de Segmentação: A campanha pode aproveitar tecnologias de segmentação de eleitores para identificar grupos específicos dentro do bairro de Rudge Ramos e adaptar suas mensagens para atender a esses grupos. Isso pode incluir eleitores com interesses comuns, como pais de família, jovens profissionais, idosos, entre outros.
#
# Essas são apenas algumas sugestões iniciais com base nos dados fornecidos. À medida que a campanha avança, é importante continuar monitorando e analisando os dados para ajustar as estratégias conforme necessário e maximizar o impacto da campanha eleitoral da Ana Nice no bairro de Rudge Ramos.
#
#
#
# Com base nos dados fornecidos, podemos elaborar algumas estratégias de campanha eleitoral para a Ana Nice no bairro de Rudge Ramos, considerando as características demográficas, sociais e econômicas do local:
#
# Segmentação por Faixa Etária: Dado o perfil demográfico do bairro, com uma significativa parcela da população na faixa de 30 a 59 anos (44,9%), a campanha pode direcionar esforços de comunicação e propostas que atendam às necessidades e interesses desse grupo etário, como políticas de emprego, educação continuada e melhorias na infraestrutura urbana.
#
# Engajamento da População Feminina: Como há uma porcentagem maior de mulheres do que homens no bairro (52,1% versus 47,9%), a campanha pode destacar políticas e programas voltados para as mulheres, como creches e assistência à maternidade, para atrair o eleitorado feminino.
#
# Aproveitamento da Diversidade Étnica: O bairro apresenta uma diversidade étnica significativa, com uma parcela considerável da população se autodeclarando como parda (9,7%) ou de outras etnias. A campanha pode promover a inclusão e a representatividade desses grupos, abordando temas de equidade racial e promovendo políticas de inclusão social.
#
# Foco na Educação e Saúde: Com uma elevada taxa de alfabetização e acesso a serviços básicos, a campanha pode enfatizar propostas relacionadas à melhoria da qualidade da educação pública, ampliação do acesso à saúde e fortalecimento do sistema de atendimento médico no bairro.
#
# Fortalecimento da Economia Local: Considerando o número significativo de atividades econômicas instaladas no bairro, a campanha pode propor medidas de estímulo ao empreendedorismo local, apoio às micro e pequenas empresas e políticas de geração de emprego e renda.
#
# Ações de Inclusão Social e Urbanização: Dado o percentual considerável de domicílios em classes de rendimento mais baixas, a campanha pode priorizar políticas de inclusão social, como moradia digna, urbanização de áreas carentes e programas de assistência social voltados para as famílias de baixa renda.
#
# Aproximação com Equipamentos Públicos e Instituições de Ensino: A campanha pode estabelecer parcerias com as escolas públicas, equipamentos de saúde e demais instituições locais para promover ações de cidadania, saúde preventiva e educação cívica, fortalecendo o vínculo comunitário e ampliando o alcance da mensagem da candidata.
#
# # Essas estratégias podem servir como ponto de partida para a elaboração de um plano de campanha mais abrangente e eficaz, levando em consideração as especificidades e demandas do bairro de Rudge Ramos e de sua população.
